# %%
import numpy as np 
import matplotlib.pyplot as plt

N = 500
p = 0.59275
#np.random.seed(69)
L = np.random.random([N,N])
plt.rcParams["figure.figsize"] = [16,8]
plt.imshow(L < p, cmap = 'hot')

# %%
def Lattice(N):
    lattice = np.zeros((N,N))
    'occupy the center'
    lattice[N//2,N//2]=1
    lattice[:,0] = lattice[0,:] = lattice[:,-1] = lattice[-1,:] = 2
    
    plt.imshow(lattice,  cmap = "hot")

#plt.imshow(Lattice(500), cmap = "hot")
Lattice(50)

# %%
def mass(lattice): 
    elements, counts = np.unique(lattice, return_counts = 1)      
    return np.mean(counts[elements!=0])

def nextstep(x,y):
    adjacents = np.array([np.array([ 0,  1]), np.array([ 1,  0]), np.array([-1,  0]), np.array([ 0, -1])])
    choice = np.random.randint(0,4)
    x += adjacents[choice][0]
    y += adjacents[choice][1]
    return x,y

def percolatingcluster(p,N,iterations):
    #np.random.seed(100)
    count = 1
    lattice = Lattice(N)
    x = y = 0
    
    for i in range(iterations):
        r = np.random.random()
        x,y = nextstep(x,y)
        if np.abs(N//2+x) < N and np.abs(N//2+y) < N:
            if lattice[N//2 + x][N//2 + y] == 0:
                if r < p: 
                    lattice[N//2 + x][N//2 + y] = 1
                    count +=1
                else: lattice[N//2 + x][N//2 + y] = 2
            else: 
                continue
    
    print(count)
    plt.imshow(lattice,cmap ='hot')
    plt.show()
    Mass = mass(lattice)
    print('mass =', Mass)
    return Mass, lattice

np.random.seed(200)
percolatingcluster(0.59275,1000,500000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-2b02389065f8> in <module>()
#      36
#      37 np.random.seed(200)
# ---> 38 percolatingcluster(0.59275,1000,500000)
#
# <ipython-input-125-2b02389065f8> in percolatingcluster(p, N, iterations)
#      20         x,y = nextstep(x,y)
#      21         if np.abs(N//2+x) < N and np.abs(N//2+y) < N:
# ---> 22             if lattice[N//2 + x][N//2 + y] == 0:
#      23                 if r < p:
#      24                     lattice[N//2 + x][N//2 + y] = 1
#
# TypeError: 'NoneType' object is not subscriptable

# %%
def threshold(n):
    
    probabilities = np.arange(0, 1.1, 0.1)
    clustersizes = np.empty_like(probabilities)
    for w in range(0,10):
        Mass, lattice = percolatingcluster(probabilities[w],n,10000)
        #size_p = []
        #clustersizes.append(Mass)
        #for i in range(trials):
            #print('trial', len(size_p))
            #print('p= ', p)
            #__, __, clustersize = labelling(n,p)
        #    size_p.append(Mass)
        #if len(size_p) != 0:
        #    clustersizes[w] = np.mean(size_p)
        #else:
        #    clustersizes[w] = 0
    #print(probabilities, clustersizes)
    return probabilities, clustersizes

threshold(50)

# %%
def Percothresholdplot():
    probabilities,clustersizes = thresh(500)
    pthreshold = probabilities[clustersizes == np.max(clustersizes)]
    print('p_c = ', pthreshold) 
    plt.figure()        
    plt.plot(probabilities, clustersizes,'--ro', lw = 2, ms = 6)
    plt.xlabel('$\mathbf{p}$', fontsize = 12) #Concentration
    plt.ylabel('$\mathbf{M}$', fontsize = 12) #Cluster Mass   
    #plt.savefig('Mvsp.png', dpi = 300, bbox_inches = 'tight')              

#Percothresholdplot()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-8c5a192b24e7> in <module>()
#       1 np.random.seed(200)
# ----> 2 percolatingcluster(0.59275,1000,500000)
#
# <ipython-input-118-84be4b15f3c4> in percolatingcluster(p, N, iterations)
#      20         x,y = nextstep(x,y)
#      21         if np.abs(N//2+x) < N and np.abs(N//2+y) < N:
# ---> 22             if lattice[N//2 + x][N//2 + y] == 0:
#      23                 if r < p:
#      24                     lattice[N//2 + x][N//2 + y] = 1
#
# TypeError: 'NoneType' object is not subscriptable
